# %%
import wrangle
import split_scale

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import explore

# %%
df = wrangle.wrangle_telco()

# %%
df.head()
# Out:
#       monthly_charges  tenure  total_charges
# 5348           109.70      71        7904.25
# 5349            84.65      63        5377.80
# 5350            90.45      65        5957.90
# 5351            45.20      54        2460.55
# 5352           116.80      72        8456.75

# %%
X = df[['monthly_charges', 'tenure']]
y = df[['total_charges']]

# %%
X_train, X_test, y_train, y_test = split_scale.split_data(X, y, 42, .8)

# %%
X_train.head()
# Out:
#       monthly_charges  tenure
# 7030             97.2      60
# 5865             64.2      46
# 5511            104.1      65
# 6534             20.2      48
# 6293             19.7      66

# %% [markdown]
# Write a function, plot_variable_pairs(dataframe) that plots all of the pairwise relationships along with the regression line for each pair.

# %%
def plot_variable_pairs(df):
    with sns.axes_style('white'):
        g = sns.pairplot(data=df, kind='reg', height=5);
    plt.show()
    return g

# %%
plot_variable_pairs(X_train)

# %% [markdown]
# Write a function, months_to_years(tenure_months, df) that returns your dataframe with a new feature tenure_years, in complete years as a customer.

# %%
tenure_months = df.tenure

# %%
df['years_as_customer'] = (tenure_months/12).astype(int)

# %%
df.years_as_customer.value_counts()
# Out:
# 5    676
# 6    343
# 4    265
# 3    166
# 2    103
# 1     83
# 0     49
# Name: years_as_customer, dtype: int64

# %%
explore.months_to_years(X_train.tenure, X_train)
# Out:
# /Users/shayaltshue/codeup-data-science/ds-methodologies-exercises/regression/explore.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['years_as_customer'] = round(tenure_months/12).astype(int)

# %%
X_train.head()
# Out:
#       monthly_charges  tenure  years_as_customer
# 7030             97.2      60                  5
# 5865             64.2      46                  4
# 5511            104.1      65                  5
# 6534             20.2      48                  4
# 6293             19.7      66                  6

# %%
x = X_train.years_as_customer
y = y_train.total_charges

# %%
sns.boxplot(x, y)

# %%
sns.boxplot(x, y)

# %%
sns.barplot(x, y)

# %%
    sns.set(style='white', palette='muted', color_codes=True)
    f, axes = plt.subplots(3, 1, figsize=(16,16))

    sns.boxplot(x, y, ax=axes[0])
    sns.barplot(x, y, ax=axes[1])
    sns.swarmplot(x, y, ax=axes[2])

# %%
explore.plot_categorical_and_continous_vars(x, y)

# %%
explore.i_like_turtles
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-7ed96e3d9fa6> in <module>
# ----> 1 explore.i_like_turtles
#
# AttributeError: module 'explore' has no attribute 'i_like_turtles'
